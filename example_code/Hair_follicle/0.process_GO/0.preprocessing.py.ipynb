# %% [markdown]
# This script describes how to extract the information we need from the downloaded GO and GOA files.
#
# Before running the following script, download:
# + GO relationship file "go-basic.obo" from http://purl.obolibrary.org/obo/go/go-basic.obo;
# + GO annotation file "mgi.gaf" for mouse from https://current.geneontology.org/annotations/mgi.gaf.gz (for other species, check the download page https://current.geneontology.org/products/pages/downloads.html and select what you need)

# %%
import os
import pandas as pd
from collections import defaultdict
os.chdir("/nfs/public/xixi/scRegulate/go")

# %% [markdown]
# # Process GO

# %%
filename = "go-basic.obo"
id1 = []
name1 = []
namespace1 = []
def1 = []
relations = []
id2 = []
with open(filename, "r") as infile:
    currentGOTerm = None
    i = 0
    for line in infile:
        line = line.strip()
        if not line: continue  # Skip empty
        if line == "[Term]":
            if i > 0:
                for i in range(len(currentGOTerm['is_a'])):
                    id1.append(currentGOTerm['id'][0])
                    name1.append(currentGOTerm["name"][0])
                    namespace1.append(currentGOTerm["namespace"][0])
                    def1.append(currentGOTerm["def"][0])
                    relations.append("is_a")
                    id2.append(str.split(currentGOTerm['is_a'][i], sep = " ")[0])
                for i in range(len(currentGOTerm['relationship'])):
                    id1.append(currentGOTerm['id'][0])
                    name1.append(currentGOTerm["name"][0])
                    namespace1.append(currentGOTerm["namespace"][0])
                    def1.append(currentGOTerm["def"][0])
                    relations.append(str.split(currentGOTerm['relationship'][i], sep = " ")[0])
                    id2.append(str.split(currentGOTerm['relationship'][i], sep = " ")[1])
            currentGOTerm = defaultdict(list)
            i = i + 1
        elif line == "[Typedef]":
            for i in range(len(currentGOTerm['is_a'])):
                id1.append(currentGOTerm['id'][0])
                name1.append(currentGOTerm["name"][0])
                namespace1.append(currentGOTerm["namespace"][0])
                def1.append(currentGOTerm["def"][0])
                relations.append("is_a")
                id2.append(str.split(currentGOTerm['is_a'][i], sep=" ")[0])
            for i in range(len(currentGOTerm['relationship'])):
                id1.append(currentGOTerm['id'][0])
                name1.append(currentGOTerm["name"][0])
                namespace1.append(currentGOTerm["namespace"][0])
                def1.append(currentGOTerm["def"][0])
                relations.append(str.split(currentGOTerm['relationship'][i], sep=" ")[0])
                id2.append(str.split(currentGOTerm['relationship'][i], sep=" ")[1])
            break
        else:  # Not [Term]
            # Only process if we're inside a [Term] environment
            if currentGOTerm is None: continue
            key, sep, val = line.partition(":")
            currentGOTerm[key].append(val.strip())
goparse = pd.DataFrame({"id1":id1, "name": name1, "namespace": namespace1, "def":def1, "relation":relations, "id2":id2})

# %%
goparse
# Out:
#               id1                                               name  \
# 0      GO:0000001                          mitochondrion inheritance
# 1      GO:0000001                          mitochondrion inheritance
# 2      GO:0000002                   mitochondrial genome maintenance
# 3      GO:0000003                                       reproduction
# 4      GO:0000006  high-affinity zinc transmembrane transporter a...
# ...           ...                                                ...
# 86692  GO:2001317                    kojic acid biosynthetic process
# 86693  GO:2001317                    kojic acid biosynthetic process
# 86694  GO:2001317                    kojic acid biosynthetic process
# 86695  GO:2001317                    kojic acid biosynthetic process
# 86696  GO:2001317                    kojic acid biosynthetic process
#
#                 namespace                                                def  \
# 0      biological_process  "The distribution of mitochondria, including t...
# 1      biological_process  "The distribution of mitochondria, including t...
# 2      biological_process  "The maintenance of the structure and integrit...
# 3      biological_process  "The production of new individuals that contai...
# 4      molecular_function  "Enables the transfer of zinc ions (Zn2+) from...
# ...                   ...                                                ...
# 86692  biological_process  "The chemical reactions and pathways resulting...
# 86693  biological_process  "The chemical reactions and pathways resulting...
# 86694  biological_process  "The chemical reactions and pathways resulting...
# 86695  biological_process  "The chemical reactions and pathways resulting...
# 86696  biological_process  "The chemical reactions and pathways resulting...
#
#       relation         id2
# 0         is_a  GO:0048308
# 1         is_a  GO:0048311
# 2         is_a  GO:0007005
# 3         is_a  GO:0008150
# 4         is_a  GO:0005385
# ...        ...         ...
# 86692     is_a  GO:0034309
# 86693     is_a  GO:0042181
# 86694     is_a  GO:0120255
# 86695     is_a  GO:1901362
# 86696     is_a  GO:2001316
#
# [86697 rows x 6 columns]

# %%
goparse.to_csv("go-organize.txt", sep = "\t", index=None)

# %% [markdown]
# # Process GOA

# %%
df_goa = pd.read_csv("mgi.gaf", sep='\t', skiprows=36, header=None)
df_goa
# Out:
# /tmp/ipykernel_2317590/4217241741.py:1: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_goa = pd.read_csv("goa_human.gaf", sep='\t', skiprows=41, header=None)
#                0           1        2             3           4   \
# 0       UniProtKB  A0A024RBG1   NUDT4B       enables  GO:0003723
# 1       UniProtKB  A0A024RBG1   NUDT4B       enables  GO:0046872
# 2       UniProtKB  A0A024RBG1   NUDT4B    located_in  GO:0005829
# 3       UniProtKB  A0A075B6H7  IGKV3-7   involved_in  GO:0002250
# 4       UniProtKB  A0A075B6H7  IGKV3-7    located_in  GO:0005886
# ...           ...         ...      ...           ...         ...
# 635263  UniProtKB      O95497     VNN1   involved_in  GO:0015939
# 635264  UniProtKB      Q15475     SIX1   involved_in  GO:0048741
# 635265  UniProtKB      P50281    MMP14  is_active_in  GO:0005615
# 635266  UniProtKB      Q8NCM2    KCNH5   involved_in  GO:0071805
# 635267  UniProtKB      Q9UKL4     GJD2       part_of  GO:0005922
#
#                     5    6   \
# 0       GO_REF:0000043  IEA
# 1       GO_REF:0000043  IEA
# 2       GO_REF:0000052  IDA
# 3       GO_REF:0000043  IEA
# 4       GO_REF:0000044  IEA
# ...                ...  ...
# 635263   GOREF:0000033  IBA
# 635264   GOREF:0000033  IBA
# 635265   GOREF:0000033  IBA
# 635266   GOREF:0000033  IBA
# 635267   GOREF:0000033  IBA
#
#                                                        7  8   \
# 0                                    UniProtKB-KW:KW-0694  F
# 1                                    UniProtKB-KW:KW-0479  F
# 2                                                     NaN  C
# 3                                    UniProtKB-KW:KW-1064  P
# 4                               UniProtKB-SubCell:SL-0039  C
# ...                                                   ... ..
# 635263  PANTHER:PTN008502038|UniProtKB:O95498|UniProtK...  P
# 635264  PANTHER:PTN002571900|ZFIN:ZDB-GENE-040426-2308...  P
# 635265  PANTHER:PTN002565758|RGD:621320|RGD:621317|RGD...  C
# 635266  PANTHER:PTN000025350|UniProtKB:O95259|RGD:6839...  P
# 635267  PANTHER:PTN008334405|UniProtKB:Q9Y6H8|MGI:MGI:...  C
#
#                                                        9           10  \
# 0       Diphosphoinositol polyphosphate phosphohydrola...      NUDT4B
# 1       Diphosphoinositol polyphosphate phosphohydrola...      NUDT4B
# 2       Diphosphoinositol polyphosphate phosphohydrola...      NUDT4B
# 3       Probable non-functional immunoglobulin kappa v...     IGKV3-7
# 4       Probable non-functional immunoglobulin kappa v...     IGKV3-7
# ...                                                   ...         ...
# 635263                                      Pantetheinase        VNN1
# 635264                              Homeobox protein SIX1        SIX1
# 635265                        Matrix metalloproteinase-14       MMP14
# 635266  Potassium voltage-gated channel subfamily H me...  KCNH5|EAG2
# 635267                       Gap junction delta-2 protein   GJD2|GJA9
#
#              11          12        13          14   15  16
# 0       protein  taxon:9606  20230911     UniProt  NaN NaN
# 1       protein  taxon:9606  20230911     UniProt  NaN NaN
# 2       protein  taxon:9606  20230619         HPA  NaN NaN
# 3       protein  taxon:9606  20230911     UniProt  NaN NaN
# 4       protein  taxon:9606  20230911     UniProt  NaN NaN
# ...         ...         ...       ...         ...  ...  ..
# 635263  protein  taxon:9606  20170228  GO_Central  NaN NaN
# 635264  protein  taxon:9606  20180309  GO_Central  NaN NaN
# 635265  protein  taxon:9606  20230405  GO_Central  NaN NaN
# 635266  protein  taxon:9606  20231108  GO_Central  NaN NaN
# 635267  protein  taxon:9606  20231108  GO_Central  NaN NaN
#
# [635268 rows x 17 columns]

# %%
set(df_goa[3])
# Out:
# {'NOT|acts_upstream_of_or_within',
#  'NOT|acts_upstream_of_or_within_negative_effect',
#  'NOT|colocalizes_with',
#  'NOT|contributes_to',
#  'NOT|enables',
#  'NOT|involved_in',
#  'NOT|is_active_in',
#  'NOT|located_in',
#  'NOT|part_of',
#  'acts_upstream_of',
#  'acts_upstream_of_negative_effect',
#  'acts_upstream_of_or_within',
#  'acts_upstream_of_or_within_negative_effect',
#  'acts_upstream_of_or_within_positive_effect',
#  'acts_upstream_of_positive_effect',
#  'colocalizes_with',
#  'contributes_to',
#  'enables',
#  'involved_in',
#  'is_active_in',
#  'located_in',
#  'part_of'}

# %%
df_goa.to_csv("go_annotation.csv", index=None)
